# %%
import os
import glob
import numpy as np
import librosa
import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense,
    Conv1D,
    MaxPooling1D,
    BatchNormalization,
    Dropout,
    GlobalAveragePooling1D,
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# --- Constants ---
DATASET_PATH = "dataset"  # Expected folder name for RAVDESS dataset
SAMPLE_RATE = 22050
N_MFCC = 40  # Number of MFCCs to extract
MAX_PAD_LEN = 174  # Maximum length of MFCC sequence (found by empirical analysis)
MODEL_FILE = "ser_model.h5"
ENCODER_FILE = "label_encoder.pkl"

# %%
# --- RAVDESS Emotion Mapping ---
# The RAVDESS filenames have the emotion code as the 3rd part (e.g., 03-01-04-...)
emotion_map = {
    "01": "neutral",
    "02": "calm",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fearful",
    "07": "disgust",
    "08": "surprised",
}
# We will use these 8 emotions
observed_emotions = emotion_map.values()

# %%
def extract_features(file_path, n_mfcc=N_MFCC, max_pad_len=MAX_PAD_LEN):
    """
    Extracts MFCC features from an audio file, then pads or truncates
    to a fixed length.
    """
    try:
        # Load audio file
        audio, sample_rate = librosa.load(
            file_path, sr=SAMPLE_RATE, res_type="kaiser_fast"
        )

        # Extract MFCCs
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)

        # Pad or truncate to fixed length
        if mfccs.shape[1] > max_pad_len:
            mfccs = mfccs[:, :max_pad_len]  # Truncate
        else:
            pad_width = max_pad_len - mfccs.shape[1]
            mfccs = np.pad(mfccs, ((0, 0), (0, pad_width)), mode="constant")

        return mfccs

    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

# %%
def load_data(dataset_path):
    """
    Loads data from the RAVDESS dataset directory.
    Assumes dataset_path contains folders like 'Actor_01', 'Actor_02', ...
    """
    print("Loading data...")
    features = []
    labels = []

    # Use glob to find all .wav files in all subdirectories
    file_pattern = os.path.join(dataset_path, "Actor_*", "*.wav")
    audio_files = glob.glob(file_pattern)

    if not audio_files:
        print(f"No audio files found in {dataset_path}.")
        print("Please make sure you have downloaded the RAVDESS dataset")
        print("and placed it in a folder named 'dataset' in the same directory.")
        return None, None

    for file_path in audio_files:
        # Filename example: 03-01-04-02-01-01-01.wav
        # The 3rd part (e.g., '04') is the emotion.
        try:
            filename = os.path.basename(file_path)
            emotion_code = filename.split("-")[2]
            emotion = emotion_map.get(emotion_code)

            if emotion not in observed_emotions:
                continue

            mfccs = extract_features(file_path)
            if mfccs is not None:
                features.append(mfccs)
                labels.append(emotion)
        except Exception as e:
            print(f"Error parsing filename {file_path}: {e}")

    print(f"Loaded {len(features)} audio files.")
    return np.array(features), np.array(labels)

# %%
def build_model(input_shape, num_classes):
    """
    Builds a 1D CNN model for speech emotion recognition.
    """
    model = Sequential()

    # Layer 1
    model.add(
        Conv1D(
            128, 5, padding="same", activation="relu", input_shape=input_shape
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))

    # Layer 2
    model.add(Conv1D(256, 5, padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))

    # Layer 3
    model.add(Conv1D(512, 5, padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))

    # Global Pooling
    model.add(GlobalAveragePooling1D())

    # Dense Layer
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.3))

    # Output Layer
    model.add(Dense(num_classes, activation="softmax"))

    # Compile
    model.compile(
        optimizer=Adam(learning_rate=0.0005),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )

    return model

# %%
# Load data
X, y = load_data(DATASET_PATH)
if X is None or y is None:
    print("None")
# Out:
# Loading data...
# Loaded 1440 audio files.

# %%
# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
num_classes = len(le.classes_)
print(f"Emotions to classify: {le.classes_}")
# Out:
# Emotions to classify: ['angry' 'calm' 'disgust' 'fearful' 'happy' 'neutral' 'sad' 'surprised']

# %%
# Transpose MFCCs to (time_steps, features) for Conv1D
# Original shape: (num_samples, n_mfcc, max_pad_len)
# Required shape: (num_samples, max_pad_len, n_mfcc)
X_transposed = np.transpose(X, (0, 2, 1))

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(
X_transposed, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)
print(f"Training data shape: {X_train.shape}")
print(f"Test data shape: {X_test.shape}")
# Out:
# Training data shape: (1152, 174, 40)
# Test data shape: (288, 174, 40)

# %%
# Build the model
input_shape = (X_train.shape[1], X_train.shape[2])  # (MAX_PAD_LEN, N_MFCC)
model = build_model(input_shape, num_classes) 
model.summary()
# Out:
# d:\SpeechEmotionRecognition\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_12 (Conv1D)              │ (None, 174, 128)       │        25,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 174, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_12 (MaxPooling1D) │ (None, 87, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 87, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_13 (Conv1D)              │ (None, 87, 256)        │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 87, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_13 (MaxPooling1D) │ (None, 43, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 43, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_14 (Conv1D)              │ (None, 43, 512)        │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 43, 512)        │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_14 (MaxPooling1D) │ (None, 21, 512)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 21, 512)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_4      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 982,664 (3.75 MB)
#  Trainable params: 980,872 (3.74 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
# Define callbacks
early_stop = EarlyStopping(monitor="val_accuracy", patience=20, restore_best_weights=True)
model_checkpoint = ModelCheckpoint(
    MODEL_FILE,
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1,
    )

# %%
# Train the model
print("Starting model training...")
history = model.fit(
    X_train,
    y_train,
    epochs=150,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stop, model_checkpoint],
    verbose=1,
    )
# Out:
# Starting model training...
# Epoch 1/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2860 - loss: 1.8349
# Epoch 1: val_accuracy improved from None to 0.11111, saving model to ser_model.h5
#
# Epoch 1: val_accuracy improved from None to 0.11111, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 105ms/step - accuracy: 0.3498 - loss: 1.6834 - val_accuracy: 0.1111 - val_loss: 5.1143
# Epoch 2/150
# Epoch 2/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4810 - loss: 1.4321
# Epoch 2: val_accuracy improved from 0.11111 to 0.14583, saving model to ser_model.h5
#
# Epoch 2: val_accuracy improved from 0.11111 to 0.14583, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.4878 - loss: 1.4011 - val_accuracy: 0.1458 - val_loss: 2.9101
# Epoch 3/150
# Epoch 3/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5851 - loss: 1.1588
# Epoch 3: val_accuracy improved from 0.14583 to 0.34722, saving model to ser_model.h5
#
# Epoch 3: val_accuracy improved from 0.14583 to 0.34722, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.5720 - loss: 1.1780 - val_accuracy: 0.3472 - val_loss: 1.7992
# Epoch 4/150
# Epoch 4/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6300 - loss: 1.0550
# Epoch 4: val_accuracy did not improve from 0.34722
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.6311 - loss: 1.0129 - val_accuracy: 0.2847 - val_loss: 2.1231
# Epoch 5/150
#
# Epoch 4: val_accuracy did not improve from 0.34722
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.6311 - loss: 1.0129 - val_accuracy: 0.2847 - val_loss: 2.1231
# Epoch 5/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6780 - loss: 0.8945
# Epoch 5: val_accuracy improved from 0.34722 to 0.48611, saving model to ser_model.h5
#
# Epoch 5: val_accuracy improved from 0.34722 to 0.48611, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.6658 - loss: 0.9224 - val_accuracy: 0.4861 - val_loss: 1.2676
# Epoch 6/150
# Epoch 6/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7012 - loss: 0.8285
# Epoch 6: val_accuracy did not improve from 0.48611
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.6988 - loss: 0.8203 - val_accuracy: 0.4514 - val_loss: 1.4755
# Epoch 7/150
#
# Epoch 6: val_accuracy did not improve from 0.48611
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.6988 - loss: 0.8203 - val_accuracy: 0.4514 - val_loss: 1.4755
# Epoch 7/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7369 - loss: 0.7448
# Epoch 7: val_accuracy improved from 0.48611 to 0.49306, saving model to ser_model.h5
#
# Epoch 7: val_accuracy improved from 0.48611 to 0.49306, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.7378 - loss: 0.7499 - val_accuracy: 0.4931 - val_loss: 1.6424
# Epoch 8/150
# Epoch 8/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7881 - loss: 0.6206
# Epoch 8: val_accuracy improved from 0.49306 to 0.53472, saving model to ser_model.h5
#
# Epoch 8: val_accuracy improved from 0.49306 to 0.53472, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.7769 - loss: 0.6298 - val_accuracy: 0.5347 - val_loss: 1.4234
# Epoch 9/150
# Epoch 9/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8143 - loss: 0.5557
# Epoch 9: val_accuracy improved from 0.53472 to 0.56944, saving model to ser_model.h5
#
# Epoch 9: val_accuracy improved from 0.53472 to 0.56944, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.8108 - loss: 0.5547 - val_accuracy: 0.5694 - val_loss: 1.4247
# Epoch 10/150
# Epoch 10/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8043 - loss: 0.5280
# Epoch 10: val_accuracy did not improve from 0.56944
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.8142 - loss: 0.5106 - val_accuracy: 0.4410 - val_loss: 1.8947
# Epoch 11/150
#
# Epoch 10: val_accuracy did not improve from 0.56944
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.8142 - loss: 0.5106 - val_accuracy: 0.4410 - val_loss: 1.8947
# Epoch 11/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8455 - loss: 0.4208
# Epoch 11: val_accuracy did not improve from 0.56944
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.8342 - loss: 0.4481 - val_accuracy: 0.4028 - val_loss: 3.1761
# Epoch 12/150
#
# Epoch 11: val_accuracy did not improve from 0.56944
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.8342 - loss: 0.4481 - val_accuracy: 0.4028 - val_loss: 3.1761
# Epoch 12/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8455 - loss: 0.4226
# Epoch 12: val_accuracy did not improve from 0.56944
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.8490 - loss: 0.4302 - val_accuracy: 0.5417 - val_loss: 1.8273
# Epoch 13/150
#
# Epoch 12: val_accuracy did not improve from 0.56944
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.8490 - loss: 0.4302 - val_accuracy: 0.5417 - val_loss: 1.8273
# Epoch 13/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8863 - loss: 0.3450
# Epoch 13: val_accuracy did not improve from 0.56944
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.8750 - loss: 0.3765 - val_accuracy: 0.5139 - val_loss: 2.2547
# Epoch 14/150
#
# Epoch 13: val_accuracy did not improve from 0.56944
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.8750 - loss: 0.3765 - val_accuracy: 0.5139 - val_loss: 2.2547
# Epoch 14/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8721 - loss: 0.3643
# Epoch 14: val_accuracy improved from 0.56944 to 0.61458, saving model to ser_model.h5
#
# Epoch 14: val_accuracy improved from 0.56944 to 0.61458, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.8802 - loss: 0.3522 - val_accuracy: 0.6146 - val_loss: 1.2826
# Epoch 15/150
# Epoch 15/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9140 - loss: 0.2469
# Epoch 15: val_accuracy did not improve from 0.61458
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9071 - loss: 0.2667 - val_accuracy: 0.5174 - val_loss: 1.8086
# Epoch 16/150
#
# Epoch 15: val_accuracy did not improve from 0.61458
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9071 - loss: 0.2667 - val_accuracy: 0.5174 - val_loss: 1.8086
# Epoch 16/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9374 - loss: 0.2114
# Epoch 16: val_accuracy did not improve from 0.61458
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9280 - loss: 0.2346 - val_accuracy: 0.5694 - val_loss: 1.6462
# Epoch 17/150
#
# Epoch 16: val_accuracy did not improve from 0.61458
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9280 - loss: 0.2346 - val_accuracy: 0.5694 - val_loss: 1.6462
# Epoch 17/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9307 - loss: 0.2250
# Epoch 17: val_accuracy did not improve from 0.61458
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9271 - loss: 0.2282 - val_accuracy: 0.5278 - val_loss: 2.3631
# Epoch 18/150
#
# Epoch 17: val_accuracy did not improve from 0.61458
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9271 - loss: 0.2282 - val_accuracy: 0.5278 - val_loss: 2.3631
# Epoch 18/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9440 - loss: 0.1764
# Epoch 18: val_accuracy did not improve from 0.61458
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9297 - loss: 0.2003 - val_accuracy: 0.5347 - val_loss: 2.0041
# Epoch 19/150
#
# Epoch 18: val_accuracy did not improve from 0.61458
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9297 - loss: 0.2003 - val_accuracy: 0.5347 - val_loss: 2.0041
# Epoch 19/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9348 - loss: 0.2149
# Epoch 19: val_accuracy improved from 0.61458 to 0.61806, saving model to ser_model.h5
#
# Epoch 19: val_accuracy improved from 0.61458 to 0.61806, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.9280 - loss: 0.2219 - val_accuracy: 0.6181 - val_loss: 1.6228
# Epoch 20/150
# Epoch 20/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9426 - loss: 0.1636
# Epoch 20: val_accuracy improved from 0.61806 to 0.66319, saving model to ser_model.h5
#
# Epoch 20: val_accuracy improved from 0.61806 to 0.66319, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9479 - loss: 0.1561 - val_accuracy: 0.6632 - val_loss: 1.3443
# Epoch 21/150
# Epoch 21/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9506 - loss: 0.1376
# Epoch 21: val_accuracy improved from 0.66319 to 0.75694, saving model to ser_model.h5
#
# Epoch 21: val_accuracy improved from 0.66319 to 0.75694, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9488 - loss: 0.1465 - val_accuracy: 0.7569 - val_loss: 0.9442
# Epoch 22/150
# Epoch 22/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9562 - loss: 0.1450
# Epoch 22: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.9531 - loss: 0.1499 - val_accuracy: 0.6389 - val_loss: 1.5750
# Epoch 23/150
#
# Epoch 22: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.9531 - loss: 0.1499 - val_accuracy: 0.6389 - val_loss: 1.5750
# Epoch 23/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9444 - loss: 0.1620
# Epoch 23: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9453 - loss: 0.1644 - val_accuracy: 0.7257 - val_loss: 1.0790
# Epoch 24/150
#
# Epoch 23: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9453 - loss: 0.1644 - val_accuracy: 0.7257 - val_loss: 1.0790
# Epoch 24/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9621 - loss: 0.1336
# Epoch 24: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.9635 - loss: 0.1203 - val_accuracy: 0.5174 - val_loss: 2.7173
# Epoch 25/150
#
# Epoch 24: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.9635 - loss: 0.1203 - val_accuracy: 0.5174 - val_loss: 2.7173
# Epoch 25/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9687 - loss: 0.0970
# Epoch 25: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.9609 - loss: 0.1196 - val_accuracy: 0.6042 - val_loss: 1.9024
# Epoch 26/150
#
# Epoch 25: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.9609 - loss: 0.1196 - val_accuracy: 0.6042 - val_loss: 1.9024
# Epoch 26/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9571 - loss: 0.1206
# Epoch 26: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9653 - loss: 0.1183 - val_accuracy: 0.6667 - val_loss: 1.1650
# Epoch 27/150
#
# Epoch 26: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9653 - loss: 0.1183 - val_accuracy: 0.6667 - val_loss: 1.1650
# Epoch 27/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9661 - loss: 0.1091
# Epoch 27: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9688 - loss: 0.1000 - val_accuracy: 0.5104 - val_loss: 2.8568
# Epoch 28/150
#
# Epoch 27: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9688 - loss: 0.1000 - val_accuracy: 0.5104 - val_loss: 2.8568
# Epoch 28/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9718 - loss: 0.0892
# Epoch 28: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.9627 - loss: 0.1062 - val_accuracy: 0.6528 - val_loss: 1.3323
# Epoch 29/150
#
# Epoch 28: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.9627 - loss: 0.1062 - val_accuracy: 0.6528 - val_loss: 1.3323
# Epoch 29/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9560 - loss: 0.1154
# Epoch 29: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.9627 - loss: 0.1019 - val_accuracy: 0.7014 - val_loss: 1.1335
# Epoch 30/150
#
# Epoch 29: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.9627 - loss: 0.1019 - val_accuracy: 0.7014 - val_loss: 1.1335
# Epoch 30/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9711 - loss: 0.0839
# Epoch 30: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9783 - loss: 0.0737 - val_accuracy: 0.7014 - val_loss: 1.0975
# Epoch 31/150
#
# Epoch 30: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9783 - loss: 0.0737 - val_accuracy: 0.7014 - val_loss: 1.0975
# Epoch 31/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9909 - loss: 0.0531
# Epoch 31: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.9870 - loss: 0.0515 - val_accuracy: 0.7569 - val_loss: 1.2150
# Epoch 32/150
#
# Epoch 31: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.9870 - loss: 0.0515 - val_accuracy: 0.7569 - val_loss: 1.2150
# Epoch 32/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9881 - loss: 0.0518
# Epoch 32: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9861 - loss: 0.0563 - val_accuracy: 0.6840 - val_loss: 1.3277
# Epoch 33/150
#
# Epoch 32: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9861 - loss: 0.0563 - val_accuracy: 0.6840 - val_loss: 1.3277
# Epoch 33/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9893 - loss: 0.0441
# Epoch 33: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9826 - loss: 0.0614 - val_accuracy: 0.7222 - val_loss: 1.3233
# Epoch 34/150
#
# Epoch 33: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9826 - loss: 0.0614 - val_accuracy: 0.7222 - val_loss: 1.3233
# Epoch 34/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9871 - loss: 0.0498
# Epoch 34: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9896 - loss: 0.0468 - val_accuracy: 0.7083 - val_loss: 1.3758
# Epoch 35/150
#
# Epoch 34: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9896 - loss: 0.0468 - val_accuracy: 0.7083 - val_loss: 1.3758
# Epoch 35/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9881 - loss: 0.0427
# Epoch 35: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.9826 - loss: 0.0535 - val_accuracy: 0.7014 - val_loss: 1.3215
# Epoch 36/150
#
# Epoch 35: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.9826 - loss: 0.0535 - val_accuracy: 0.7014 - val_loss: 1.3215
# Epoch 36/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9859 - loss: 0.0415
# Epoch 36: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.9878 - loss: 0.0430 - val_accuracy: 0.6389 - val_loss: 1.7706
# Epoch 37/150
#
# Epoch 36: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.9878 - loss: 0.0430 - val_accuracy: 0.6389 - val_loss: 1.7706
# Epoch 37/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9799 - loss: 0.0655
# Epoch 37: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.9774 - loss: 0.0714 - val_accuracy: 0.7569 - val_loss: 1.0107
# Epoch 38/150
#
# Epoch 37: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.9774 - loss: 0.0714 - val_accuracy: 0.7569 - val_loss: 1.0107
# Epoch 38/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9768 - loss: 0.0649
# Epoch 38: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9705 - loss: 0.0804 - val_accuracy: 0.5694 - val_loss: 2.4478
# Epoch 39/150
#
# Epoch 38: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9705 - loss: 0.0804 - val_accuracy: 0.5694 - val_loss: 2.4478
# Epoch 39/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9730 - loss: 0.0984
# Epoch 39: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9740 - loss: 0.0923 - val_accuracy: 0.7396 - val_loss: 1.2003
# Epoch 40/150
#
# Epoch 39: val_accuracy did not improve from 0.75694
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9740 - loss: 0.0923 - val_accuracy: 0.7396 - val_loss: 1.2003
# Epoch 40/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9875 - loss: 0.0512
# Epoch 40: val_accuracy improved from 0.75694 to 0.79167, saving model to ser_model.h5
#
# Epoch 40: val_accuracy improved from 0.75694 to 0.79167, saving model to ser_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9826 - loss: 0.0548 - val_accuracy: 0.7917 - val_loss: 0.9604
# Epoch 41/150
# Epoch 41/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9858 - loss: 0.0560
# Epoch 41: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9826 - loss: 0.0672 - val_accuracy: 0.6840 - val_loss: 1.7901
# Epoch 42/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9709 - loss: 0.0830
# Epoch 42: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9757 - loss: 0.0709 - val_accuracy: 0.7292 - val_loss: 1.2538
# Epoch 43/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9816 - loss: 0.0612
# Epoch 43: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.9809 - loss: 0.0556 - val_accuracy: 0.7118 - val_loss: 1.3650
# Epoch 44/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9852 - loss: 0.0409
# Epoch 44: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9800 - loss: 0.0587 - val_accuracy: 0.6667 - val_loss: 1.7735
# Epoch 45/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9813 - loss: 0.0551
# Epoch 45: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.9774 - loss: 0.0576 - val_accuracy: 0.5243 - val_loss: 3.6971
# Epoch 46/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9870 - loss: 0.0427
# Epoch 46: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.9783 - loss: 0.0619 - val_accuracy: 0.6667 - val_loss: 1.6430
# Epoch 47/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9734 - loss: 0.0785
# Epoch 47: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.9766 - loss: 0.0793 - val_accuracy: 0.6458 - val_loss: 2.2468
# Epoch 48/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9619 - loss: 0.0904
# Epoch 48: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9714 - loss: 0.0739 - val_accuracy: 0.6354 - val_loss: 1.7627
# Epoch 49/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9807 - loss: 0.0621
# Epoch 49: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9748 - loss: 0.0815 - val_accuracy: 0.6736 - val_loss: 1.6494
# Epoch 50/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9867 - loss: 0.0528
# Epoch 50: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.9800 - loss: 0.0606 - val_accuracy: 0.6910 - val_loss: 1.3546
# Epoch 51/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9903 - loss: 0.0506
# Epoch 51: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.9887 - loss: 0.0479 - val_accuracy: 0.4167 - val_loss: 4.9090
# Epoch 52/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9793 - loss: 0.0575
# Epoch 52: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.9809 - loss: 0.0521 - val_accuracy: 0.6875 - val_loss: 1.6007
# Epoch 53/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9888 - loss: 0.0371
# Epoch 53: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.9852 - loss: 0.0442 - val_accuracy: 0.7535 - val_loss: 1.0854
# Epoch 54/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9938 - loss: 0.0237
# Epoch 54: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.9931 - loss: 0.0260 - val_accuracy: 0.6562 - val_loss: 1.6932
# Epoch 55/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9888 - loss: 0.0322
# Epoch 55: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.9896 - loss: 0.0327 - val_accuracy: 0.7326 - val_loss: 1.2629
# Epoch 56/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9841 - loss: 0.0551
# Epoch 56: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9818 - loss: 0.0647 - val_accuracy: 0.7431 - val_loss: 1.7227
# Epoch 57/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9839 - loss: 0.0440
# Epoch 57: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9887 - loss: 0.0372 - val_accuracy: 0.6215 - val_loss: 2.3589
# Epoch 58/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9877 - loss: 0.0283
# Epoch 58: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9887 - loss: 0.0292 - val_accuracy: 0.6493 - val_loss: 1.6592
# Epoch 59/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9899 - loss: 0.0324
# Epoch 59: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9887 - loss: 0.0336 - val_accuracy: 0.7500 - val_loss: 1.3672
# Epoch 60/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9897 - loss: 0.0292
# Epoch 60: val_accuracy did not improve from 0.79167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9870 - loss: 0.0344 - val_accuracy: 0.6979 - val_loss: 2.0864

# %%
# Evaluate the best model on test set
print("\nEvaluating the best model...")
best_model = model  # EarlyStopping restored best weights
test_loss, test_accuracy = best_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy*100:.2f}%")
# Out:
# Evaluating the best model...
# Test Loss: 0.9604
# Test Accuracy: 79.17%

# %%
# Save the label encoder
try:
    joblib.dump(le, ENCODER_FILE)
    print(f"Label encoder saved to {ENCODER_FILE}")
    print(f"Model saved to {MODEL_FILE}")
    print("\nTraining complete!")
except Exception as e:
    print(f"Error saving label encoder: {e}")
# Out:
# Label encoder saved to label_encoder.pkl
# Model saved to ser_model.h5
#
# Training complete!
